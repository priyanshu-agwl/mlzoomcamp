# %%
import pandas as pd 
import cv2 
from glob import glob 
import matplotlib.pylab as plt 
import numpy as np

# %%
cornfiles= glob('../input/kaggle-pog-series-s01e03/corn/train/*.png')

# %%
img_mpl=plt.imread(cornfiles[1])

# %%
pd.Series(img_mpl.flatten()).plot(kind='hist',bins=50,title='Distribution of pixels')
plt.show()
